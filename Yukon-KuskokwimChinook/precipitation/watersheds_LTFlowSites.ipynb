# %% [markdown]
# This script creates watersheds for long-term (at last 10 years of data) streamflow monitoring sites managed by USGS and ECCC in the project study area.
#
# Using the MERIT-Basins stream network and catchments. These were created
# using a 90m DEM and TauDEM.
#
# NOTE: May need to review point locations, first try see if they fall correctly within a merit-basins catchment
#
# 1. intersect points with catchments to get catchment ID
# 2. create list of IDs for which we want watersheds
# 3. use loop to identify upstream catchments
# 4. merge catchments to create watersheds
# 5. use spatial join to get location names onto watersheds (location_short matches site spreadsheet created by Megan on google drive -- her populations are linked to major spawning areas).

# %%
# get list of catchment ids for sites

import arcpy
import pandas as pd

ayk_chinook_gdb = r"W:\GIS\AYK_Chinook\AYK_Chinook.gdb"
arcpy.env.workspace = ayk_chinook_gdb
arcpy.env.overwriteOutput = True
arcpy.env.qualifiedFieldNames = False
sr = arcpy.SpatialReference(4326)  #'WGS 1984'
arcpy.env.outputCoordinateSystem = sr

points = ayk_chinook_gdb + "\\lt_flow_sites"
cats = r"W:\GIS\MERIT-Basins\cat_pfaf_8_MERIT_Hydro_v07_Basins_v01_bugfix1.shp"
idList = []
outcats = ayk_chinook_gdb + "\\cats_ltflow_int"

arcpy.MakeFeatureLayer_management(points, "pointsTempLayer")
arcpy.MakeFeatureLayer_management(cats, "tempLayer")
arcpy.SelectLayerByLocation_management("templayer", "INTERSECT", "pointsTempLayer")
arcpy.CopyFeatures_management("templayer", outcats)

fields = arcpy.ListFields("tempLayer")
for field in fields:
    print("{0}".format(field.name))
with arcpy.da.SearchCursor("tempLayer", ["COMID"]) as cursor:
    for row in cursor:
        idList.append(row[0])

print(len(idList))
# Out:
# FID
# Shape
# COMID
# unitarea
# 78

# %%
# Find upstream COMIDs and merge to create watersheds in memory and put in a list


import os
import arcpy
import pandas as pd

ayk_chinook_gdb = r"W:\GIS\AYK_Chinook\AYK_Chinook.gdb"
arcpy.env.workspace = ayk_chinook_gdb
arcpy.env.overwriteOutput = True
arcpy.env.qualifiedFieldNames = False
sr = arcpy.SpatialReference(4326)  #'WGS 1984'
arcpy.env.outputCoordinateSystem = sr

# Start timing function
processStart = time.time()
processStartdt = datetime.datetime.now()
streams = r"W:\GIS\MERIT-Basins\riv_pfaf_8_MERIT_Hydro_v07_Basins_v01_bugfix1.shp"
cats = r"W:\GIS\MERIT-Basins\cat_pfaf_8_MERIT_Hydro_v07_Basins_v01_bugfix1.shp"

# Get list of index names for cats and add index if not already created
index_names = [i.name for i in arcpy.ListIndexes(cats)]
print(index_names)
if 'comid_index' not in index_names:
    print (f'Creating index for {cats}')
    arcpy.AddIndex_management(cats, "COMID", "comid_index")
else:
    print(f'{cats} Indexed')

fields = arcpy.ListFields(streams)
for field in fields:
    print("{0}".format(field.name))

str_df = pd.DataFrame(arcpy.da.FeatureClassToNumPyArray(streams, ("COMID", "up1", "up2", "up3")))
hws_codes = [0]

#idList if doing ALL watersheds.
wtds_out = list()
c = 1
for id in idList:
    print(f"{c}. Starting watershed for: " + str(id))
    rec = [id]
    up_ids = []
    sum_rec = sum(rec)

    while(sum_rec > 0):
        up_ids.append(rec)
        rec = str_df.loc[str_df["COMID"].isin(rec), ("up1", "up2", "up3")]
        rec = pd.concat([rec['up1'], rec['up2'], rec['up3']])
        sum_rec = sum(rec)

    #up_ids is a list with more than numbers, use extend to only keep numeric comids
    newup_ids = []
    for x in up_ids:
        newup_ids.extend(x)

    tempLayer = "catsLyr"
    expression = '"COMID" IN ({0})'.format(', '.join(map(str, newup_ids)) or 'NULL')
    arcpy.MakeFeatureLayer_management(cats, tempLayer)
    arcpy.management.SelectLayerByAttribute(tempLayer, "NEW_SELECTION", expression, None)
    print("Starting dissolve")
    #outdis = "memory/wtd_" + str(round(id))
    outwtd = os.path.join('in_memory', "wtd_" + str(round(id)))
    arcpy.Dissolve_management(tempLayer, outwtd)
    #watershed = arcpy.EliminatePolygonPart_management(dis, outwtd,"PERCENT", "0 SquareKilometers", 90, "CONTAINED_ONLY")
    arcpy.AddField_management(outwtd,"outlet_comid")
    arcpy.CalculateField_management(outwtd, "outlet_comid", id)
    print("Watershed created at:" + outwtd)
    wtds_out.append(outwtd)
    c=c+1

print(wtds_out)

# End timing
processEnd = time.time()
processElapsed = int(processEnd - processStart)
processSuccess_time = datetime.datetime.now()

# Report success
print(f'Process completed at {processSuccess_time.strftime("%Y-%m-%d %H:%M")} '
      f'(Elapsed time: {datetime.timedelta(seconds=processElapsed)})')
# Out:
# ['COMID']
# Creating index for W:\GIS\MERIT-Basins\cat_pfaf_8_MERIT_Hydro_v07_Basins_v01_bugfix1.shp
# FID
# Shape
# COMID
# lengthkm
# lengthdir
# sinuosity
# slope
# uparea
# order
# strmDrop_t
# slope_taud
# NextDownID
# maxup
# up1
# up2
# up3
# up4
# 1. Starting watershed for: 81022626.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81022626
# 2. Starting watershed for: 81013033.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81013033
# 3. Starting watershed for: 81034749.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81034749
# 4. Starting watershed for: 81017096.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81017096
# 5. Starting watershed for: 81034577.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81034577
# 6. Starting watershed for: 81034502.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81034502
# 7. Starting watershed for: 81016747.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81016747
# 8. Starting watershed for: 81034392.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81034392
# 9. Starting watershed for: 81016661.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81016661
# 10. Starting watershed for: 81034197.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81034197
# 11. Starting watershed for: 81034085.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81034085
# 12. Starting watershed for: 81034013.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81034013
# 13. Starting watershed for: 81007021.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81007021
# 14. Starting watershed for: 81006891.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81006891
# 15. Starting watershed for: 81006886.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81006886
# 16. Starting watershed for: 81003610.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81003610
# 17. Starting watershed for: 81006811.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81006811
# 18. Starting watershed for: 81011135.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81011135
# 19. Starting watershed for: 81006643.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81006643
# 20. Starting watershed for: 81010898.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81010898
# 21. Starting watershed for: 81030945.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81030945
# 22. Starting watershed for: 81003296.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81003296
# 23. Starting watershed for: 81020216.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81020216
# 24. Starting watershed for: 81030415.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81030415
# 25. Starting watershed for: 81010275.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81010275
# 26. Starting watershed for: 81015259.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81015259
# 27. Starting watershed for: 81015189.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81015189
# 28. Starting watershed for: 81019656.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81019656
# 29. Starting watershed for: 81015122.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81015122
# 30. Starting watershed for: 81025098.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81025098
# 31. Starting watershed for: 81030128.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81030128
# 32. Starting watershed for: 81025055.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81025055
# 33. Starting watershed for: 81030061.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81030061
# 34. Starting watershed for: 81015017.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81015017
# 35. Starting watershed for: 81014754.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81014754
# 36. Starting watershed for: 81019153.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81019153
# 37. Starting watershed for: 81029676.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81029676
# 38. Starting watershed for: 81014678.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81014678
# 39. Starting watershed for: 81014662.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81014662
# 40. Starting watershed for: 81019068.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81019068
# 41. Starting watershed for: 81014576.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81014576
# 42. Starting watershed for: 81014557.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81014557
# 43. Starting watershed for: 81014545.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81014545
# 44. Starting watershed for: 81019005.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81019005
# 45. Starting watershed for: 81014516.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81014516
# 46. Starting watershed for: 81024537.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81024537
# 47. Starting watershed for: 81018957.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81018957
# 48. Starting watershed for: 81014467.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81014467
# 49. Starting watershed for: 81024473.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81024473
# 50. Starting watershed for: 81014422.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81014422
# 51. Starting watershed for: 81029435.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81029435
# 52. Starting watershed for: 81018859.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81018859
# 53. Starting watershed for: 81018832.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81018832
# 54. Starting watershed for: 81024318.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81024318
# 55. Starting watershed for: 81014351.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81014351
# 56. Starting watershed for: 81014341.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81014341
# 57. Starting watershed for: 81029358.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81029358
# 58. Starting watershed for: 81014329.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81014329
# 59. Starting watershed for: 81024269.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81024269
# 60. Starting watershed for: 81029299.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81029299
# 61. Starting watershed for: 81024148.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81024148
# 62. Starting watershed for: 81029227.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81029227
# 63. Starting watershed for: 81029212.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81029212
# 64. Starting watershed for: 81018570.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81018570
# 65. Starting watershed for: 81024065.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81024065
# 66. Starting watershed for: 81018520.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81018520
# 67. Starting watershed for: 81024059.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81024059
# 68. Starting watershed for: 81024048.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81024048
# 69. Starting watershed for: 81018496.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81018496
# 70. Starting watershed for: 81024014.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81024014
# 71. Starting watershed for: 81018427.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81018427
# 72. Starting watershed for: 81023970.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81023970
# 73. Starting watershed for: 81023916.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81023916
# 74. Starting watershed for: 81023852.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81023852
# 75. Starting watershed for: 81023826.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81023826
# 76. Starting watershed for: 81023732.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81023732
# 77. Starting watershed for: 81023684.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81023684
# 78. Starting watershed for: 81023601.0
# Starting dissolve
# Watershed created at:in_memory\wtd_81023601
# ['in_memory\\wtd_81022626', 'in_memory\\wtd_81013033', 'in_memory\\wtd_81034749', 'in_memory\\wtd_81017096', 'in_memory\\wtd_81034577', 'in_memory\\wtd_81034502', 'in_memory\\wtd_81016747', 'in_memory\\wtd_81034392', 'in_memory\\wtd_81016661', 'in_memory\\wtd_81034197', 'in_memory\\wtd_81034085', 'in_memory\\wtd_81034013', 'in_memory\\wtd_81007021', 'in_memory\\wtd_81006891', 'in_memory\\wtd_81006886', 'in_memory\\wtd_81003610', 'in_memory\\wtd_81006811', 'in_memory\\wtd_81011135', 'in_memory\\wtd_81006643', 'in_memory\\wtd_81010898', 'in_memory\\wtd_81030945', 'in_memory\\wtd_81003296', 'in_memory\\wtd_81020216', 'in_memory\\wtd_81030415', 'in_memory\\wtd_81010275', 'in_memory\\wtd_81015259', 'in_memory\\wtd_81015189', 'in_memory\\wtd_81019656', 'in_memory\\wtd_81015122', 'in_memory\\wtd_81025098', 'in_memory\\wtd_81030128', 'in_memory\\wtd_81025055', 'in_memory\\wtd_81030061', 'in_memory\\wtd_81015017', 'in_memory\\wtd_81014754', 'in_memory\\wtd_81019153', 'in_memory\\wtd_81029676', 'in_memory\\wtd_81014678', 'in_memory\\wtd_81014662', 'in_memory\\wtd_81019068', 'in_memory\\wtd_81014576', 'in_memory\\wtd_81014557', 'in_memory\\wtd_81014545', 'in_memory\\wtd_81019005', 'in_memory\\wtd_81014516', 'in_memory\\wtd_81024537', 'in_memory\\wtd_81018957', 'in_memory\\wtd_81014467', 'in_memory\\wtd_81024473', 'in_memory\\wtd_81014422', 'in_memory\\wtd_81029435', 'in_memory\\wtd_81018859', 'in_memory\\wtd_81018832', 'in_memory\\wtd_81024318', 'in_memory\\wtd_81014351', 'in_memory\\wtd_81014341', 'in_memory\\wtd_81029358', 'in_memory\\wtd_81014329', 'in_memory\\wtd_81024269', 'in_memory\\wtd_81029299', 'in_memory\\wtd_81024148', 'in_memory\\wtd_81029227', 'in_memory\\wtd_81029212', 'in_memory\\wtd_81018570', 'in_memory\\wtd_81024065', 'in_memory\\wtd_81018520', 'in_memory\\wtd_81024059', 'in_memory\\wtd_81024048', 'in_memory\\wtd_81018496', 'in_memory\\wtd_81024014', 'in_memory\\wtd_81018427', 'in_memory\\wtd_81023970', 'in_memory\\wtd_81023916', 'in_memory\\wtd_81023852', 'in_memory\\wtd_81023826', 'in_memory\\wtd_81023732', 'in_memory\\wtd_81023684', 'in_memory\\wtd_81023601']
# Process completed at 2022-12-01 11:58 (Elapsed time: 0:02:14)

# %%
# Merge all watersheds into one feature class using list from code chunk above.
import arcpy
arcpy.env.overwriteOutput = True

arcpy.env.workspace = ayk_chinook_gdb
wtd_output = "wtds_ltflow_merge"
wtd_merge = arcpy.Merge_management(wtds_out, wtd_output)

print('Process complete')
# Out:
# Process complete

# %%
# Get fields from points feature class onto watersheds
# 1. spatial join between points and comid in catchments.
# 2. use join fields to merge point attributes to watersheds using comids.
# 3. add watershed area

import arcpy
import pandas as pd

ayk_chinook_gdb = r"W:\GIS\AYK_Chinook\AYK_Chinook.gdb"
arcpy.env.workspace = ayk_chinook_gdb
arcpy.env.overwriteOutput = True
arcpy.env.qualifiedFieldNames = False
sr = arcpy.SpatialReference(4326)  #'WGS 1984'
arcpy.env.outputCoordinateSystem = sr

points = os.path.join(ayk_chinook_gdb, "lt_flow_sites")
out_pts = os.path.join(ayk_chinook_gdb, "ltflow_sites_comid")
wtds = os.path.join(ayk_chinook_gdb, "wtds_ltflow_merge")
cats = os.path.join(ayk_chinook_gdb, "cats_ltflow_int")

arcpy.MakeFeatureLayer_management(points, "pointsTempLayer")

arcpy.SpatialJoin_analysis("pointsTempLayer", cats, out_pts)
arcpy.management.JoinField(wtds, "outlet_comid", out_pts, "COMID", "SiteID;Waterbody_name", "NOT_USE_FM", None)

arcpy.AddGeometryAttributes_management(wtds, "AREA_GEODESIC","", "SQUARE_KILOMETERS")
# Out:
# <Result 'W:\\GIS\\AYK_Chinook\\AYK_Chinook.gdb\\wtds_ltflow_merge'>
